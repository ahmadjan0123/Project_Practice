# %%
import os

# %%
from dotenv import load_dotenv

# %%
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_community.document_loaders import TextLoader,PyMuPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_core.prompts import ChatPromptTemplate

# %%
# load the environment variables
load_dotenv()
# Out:
# True

# %% [markdown]
# <h2>LOAD THE DATA</h2>

# %%
loader = PyMuPDFLoader('attention-is-all-you-need-Paper.pdf')
pages = loader.load()

# %% [markdown]
# <h2>TEXT SPLIITER / CHUNKING</h2>

# %%
text_spliiter = RecursiveCharacterTextSplitter(
    chunk_size = 500,
    chunk_overlap = 20
)

# %%
chunks = text_spliiter.split_documents(pages)

# %%
print('the number of chunks',len(chunks))
# Out:
# the number of chunks 76

# %% [markdown]
# <h2>EMBEDDING</h2>

# %%
embedding = OpenAIEmbeddings(
        model = 'text-embedding-3-small'
)

# %% [markdown]
# <h2>Create vector database</h2>

# %%
vector_store = FAISS.from_documents(
    chunks,
    embedding
)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 vector_store = FAISS.from_documents(
#       2     chunks,
#       3     embedding
#       4 )
#
# File e:\GEN-AI-PROJECTS\genai-env\Lib\site-packages\langchain_core\vectorstores\base.py:814, in VectorStore.from_documents(cls, documents, embedding, **kwargs)
#     811     if any(ids):
#     812         kwargs["ids"] = ids
# --> 814 return cls.from_texts(texts, embedding, metadatas=metadatas, **kwargs)
#
# File e:\GEN-AI-PROJECTS\genai-env\Lib\site-packages\langchain_community\vectorstores\faiss.py:1043, in FAISS.from_texts(cls, texts, embedding, metadatas, ids, **kwargs)
#    1016 @classmethod
#    1017 def from_texts(
#    1018     cls,
#    (...)   1023     **kwargs: Any,
#    1024 ) -> FAISS:
#    1025     """Construct FAISS wrapper from raw documents.
#    1026
#    1027     This is a user friendly interface that:
#    (...)   1041             faiss = FAISS.from_texts(texts, embeddings)
#    1042     """
# -> 1043     embeddings = embedding.embed_documents(texts)
#    1044     return cls.__from(
#    1045         texts,
#    1046         embeddings,
#    (...)   1050         **kwargs,
#    1051     )
#
# File e:\GEN-AI-PROJECTS\genai-env\Lib\site-packages\langchain_openai\embeddings\base.py:757, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size, **kwargs)
#     754 # Unconditionally call _get_len_safe_embeddings to handle length safety.
#     755 # This could be optimized to avoid double work when all texts are short enough.
#     756 engine = cast(str, self.deployment)
# --> 757 return self._get_len_safe_embeddings(
#     758     texts, engine=engine, chunk_size=chunk_size, **kwargs
#     759 )
#
# File e:\GEN-AI-PROJECTS\genai-env\Lib\site-packages\langchain_openai\embeddings\base.py:624, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size, **kwargs)
#     622 # Make API call with this batch
#     623 batch_tokens = tokens[i:batch_end]
# --> 624 response = self.client.create(input=batch_tokens, **client_kwargs)
#     625 if not isinstance(response, dict):
#     626     response = response.model_dump()
#
# File e:\GEN-AI-PROJECTS\genai-env\Lib\site-packages\openai\resources\embeddings.py:136, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     130             embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     131                 base64.b64decode(data), dtype="float32"
#     132             ).tolist()
#     134     return obj
# --> 136 return self._post(
#     137     "/embeddings",
#     138     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     139     options=make_request_options(
#     140         extra_headers=extra_headers,
#     141         extra_query=extra_query,
#     142         extra_body=extra_body,
#     143         timeout=timeout,
#     144         post_parser=parser,
#     145         security={"bearer_auth": True},
#     146     ),
#     147     cast_to=CreateEmbeddingResponse,
#     148 )
#
# File e:\GEN-AI-PROJECTS\genai-env\Lib\site-packages\openai\_base_client.py:1381, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1372     warnings.warn(
#    1373         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1374         "Please pass raw bytes via the `content` parameter instead.",
#    1375         DeprecationWarning,
#    1376         stacklevel=2,
#    1377     )
#    1378 opts = FinalRequestOptions.construct(
#    1379     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1380 )
# -> 1381 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File e:\GEN-AI-PROJECTS\genai-env\Lib\site-packages\openai\_base_client.py:1154, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1151             err.response.read()
#    1153         log.debug("Re-raising status error")
# -> 1154         raise self._make_status_error_from_response(err.response) from None
#    1156     break
#    1158 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
